# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ######  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

# %%
r = requests.get(url)

# %% [raw]
# r.status_code

# %%
data_json = r.json()

# %%
pd.DataFrame((data_json['items']))
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0        40740        Município       Petrópolis   3303906  RJ
# 1        60057        Município           Paraty   3303807  RJ
# 2        13589        Município   Rio de Janeiro   3304557  RJ
# 3        13653        Município  Duque de Caxias   3301702  RJ
# 4         9990        Município   Barra do Piraí   3300308  RJ
# ..         ...              ...              ...       ...  ..
# 228       5464        Município       Petrópolis   3303906  RJ
# 229      12288        Município  Duque de Caxias   3301702  RJ
# 230      12298        Município           Quatis   3304128  RJ
# 231      12509        Município    Volta Redonda   3306305  RJ
# 232      29667        Município   Rio de Janeiro   3304557  RJ
#
#                   num_pvl                                             status  \
# 0    PVL02.008447/2019-25                                           Deferido
# ...

# %%
# 2) Seu código aqui

pd.DataFrame((data_json['items']))['status'].value_counts()
# Out:
# Deferido                                                 91
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           23
# Deferido (PVL-IF)                                        16
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           4
# Em retificação pelo interessado (PVL-IF)                  1
# Pendente de regularização                                 1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui

pd.DataFrame((data_json['items'])).dtypes
# Out:
# id_pleito                  int64
# tipo_interessado          object
# interessado               object
# cod_ibge                   int64
# uf                        object
# num_pvl                   object
# status                    object
# num_processo              object
# data_protocolo            object
# tipo_operacao             object
# finalidade                object
# tipo_credor               object
# credor                    object
# moeda                     object
# valor                    float64
# pvl_assoc_divida           int64
# pvl_contradado_credor      int64
# data_status               object
# dtype: object

# %%
datas = pd.DataFrame((data_json['items']))

# %%
divisao = datas['data_status'].str.split('/')
divisao.head()
# Out:
# 0    [06, 08, 2020]
# 1    [29, 07, 2022]
# 2    [26, 06, 2007]
# 3    [13, 03, 2007]
# 4    [30, 10, 2008]
# Name: data_status, dtype: object

# %%
ano = divisao.str.get(2)
ano
# Out:
# 0      2020
# 1      2022
# 2      2007
# 3      2007
# 4      2008
#        ...
# 228    2010
# 229    2013
# 230    2012
# 231    2014
# 232    2018
# Name: data_status, Length: 233, dtype: object

# %%
datas['ano_status'] = ano
datas
# Out:
#      id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0        40740        Município       Petrópolis   3303906  RJ
# 1        60057        Município           Paraty   3303807  RJ
# 2        13589        Município   Rio de Janeiro   3304557  RJ
# 3        13653        Município  Duque de Caxias   3301702  RJ
# 4         9990        Município   Barra do Piraí   3300308  RJ
# ..         ...              ...              ...       ...  ..
# 228       5464        Município       Petrópolis   3303906  RJ
# 229      12288        Município  Duque de Caxias   3301702  RJ
# 230      12298        Município           Quatis   3304128  RJ
# 231      12509        Município    Volta Redonda   3306305  RJ
# 232      29667        Município   Rio de Janeiro   3304557  RJ
#
#                   num_pvl                                             status  \
# 0    PVL02.008447/2019-25                                           Deferido
# ...

# %%
# 4) Seu código aqui

datas['ano_status'].value_counts()
# Out:
# 2008    37
# 2007    29
# 2014    20
# 2010    19
# 2019    17
# 2020    15
# 2013    15
# 2012    13
# 2022    12
# 2011    10
# 2015     9
# 2009     9
# 2017     5
# 2021     5
# 2018     4
# 2002     4
# 2006     4
# 2016     4
# 2004     1
# 2003     1
# Name: ano_status, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?'

# %%
r2 = requests.get(url)

# %%
r2.status_code
# Out:
# 200

# %%
data2_json = r2.json()

# %%
datalake = pd.DataFrame((data2_json['items']))
datalake.head()
# Out:
#    id_pleito tipo_interessado      interessado  cod_ibge  uf num_pvl  \
# 0      15225        Município      Campo Largo   4104204  PR    None
# 1      15251        Município  Nova Candelária   4313011  RS    None
# 2      14371        Município       Ronda Alta   4316105  RS    None
# 3      15469        Município   Pedras Grandes   4212403  SC    None
# 4      15478        Município        Itaperuçu   4111258  PR    None
#
#      status          num_processo        data_protocolo  \
# 0  Deferido  19406.000155/2010-91  2010-03-29T03:00:00Z
# 1  Deferido  19406.000158/2009-91  2009-07-02T03:00:00Z
# 2  Deferido  19406.000060/2009-34  2009-09-09T03:00:00Z
# 3  Deferido  19406.000183/2002-07  2002-07-31T03:00:00Z
# 4  Deferido  19406.000184/2002-43  2002-07-26T03:00:00Z
#
#                  tipo_operacao  \
# 0  Operação contratual interna
# 1  Operação contratual interna
# 2  Operação contratual interna
# 3  Operação contratual interna
# 4  Operação contratual interna
#
# ...

# %%
UF = 'BA'

# %%
tipo = 'Município'

# %%
#1) Seu código aqui

datalake.loc[(datalake['uf'] == UF) & (datalake['tipo_interessado'] == tipo)]
# Out:
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# 11        18357        Município                  Xique-Xique   2933604  BA
# 20        36668        Município            Riacho de Santana   2926400  BA
# 44        45652        Município                     Milagres   2921302  BA
# 95        54069        Município               Várzea da Roça   2933059  BA
# 97        61161        Município            Itaguaçu da Bahia   2915353  BA
# ...         ...              ...                          ...       ...  ..
# 4796       6137        Município  Livramento de Nossa Senhora   2919504  BA
# 4898       6198        Município                      Angical   2901403  BA
# 4943      11221        Município                       Itatim   2916856  BA
# 4955      10436        Município                      Canudos   2906824  BA
# 4975       6400        Município              Barra do Mendes   2903003  BA
#
# ...

# %%
# 2) Seu código aqui

# %%
datalake_mg = datalake.loc[(datalake['uf'] == 'MG') & (datalake['tipo_interessado'] == 'Estado')]
datalake_mg
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 245       13549           Estado  Minas Gerais        31  MG
# 375       13672           Estado  Minas Gerais        31  MG
# 617       13695           Estado  Minas Gerais        31  MG
# 714       13587           Estado  Minas Gerais        31  MG
# 1393      20458           Estado  Minas Gerais        31  MG
# 2740      10294           Estado  Minas Gerais        31  MG
# 2973      11571           Estado  Minas Gerais        31  MG
# 3521       6811           Estado  Minas Gerais        31  MG
# 3769      13275           Estado  Minas Gerais        31  MG
# 4008      11132           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 245                   None                                           Deferido
# 375                   None  Encaminhado à PGFN com manifestação técnica fa...
# ...

# %%
# 271

datalake_mg.loc[(datalake_mg['status'] == 'Arquivado por decurso de prazo')]

# Zero.
# Out:
# Empty DataFrame
# Columns: [id_pleito, tipo_interessado, interessado, cod_ibge, uf, num_pvl, status, num_processo, data_protocolo, tipo_operacao, finalidade, tipo_credor, credor, moeda, valor, pvl_assoc_divida, pvl_contradado_credor, data_status]
# Index: []

# %%
# 3

datalake_ba = datalake.loc[(datalake['uf'] == 'BA') & (datalake['tipo_interessado'] == 'Município')]
datalake_ba
# Out:
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# 11        18357        Município                  Xique-Xique   2933604  BA
# 20        36668        Município            Riacho de Santana   2926400  BA
# 44        45652        Município                     Milagres   2921302  BA
# 95        54069        Município               Várzea da Roça   2933059  BA
# 97        61161        Município            Itaguaçu da Bahia   2915353  BA
# ...         ...              ...                          ...       ...  ..
# 4796       6137        Município  Livramento de Nossa Senhora   2919504  BA
# 4898       6198        Município                      Angical   2901403  BA
# 4943      11221        Município                       Itatim   2916856  BA
# 4955      10436        Município                      Canudos   2906824  BA
# 4975       6400        Município              Barra do Mendes   2903003  BA
#
# ...

# %%
datalake_ba.loc[(datalake_ba['status'] == 'Deferido')]

# 87 solicitações deferidas.
# Out:
#       id_pleito tipo_interessado             interessado  cod_ibge  uf  \
# 11        18357        Município             Xique-Xique   2933604  BA
# 20        36668        Município       Riacho de Santana   2926400  BA
# 139       51710        Município          Barra do Rocha   2903102  BA
# 221       18598        Município                  Wagner   2933406  BA
# 228       11168        Município                Olindina   2923100  BA
# ...         ...              ...                     ...       ...  ..
# 4141      33248        Município                Camaçari   2905701  BA
# 4198      38670        Município            Paulo Afonso   2924009  BA
# 4563       7290        Município  Oliveira dos Brejinhos   2923209  BA
# 4680      18391        Município     Wenceslau Guimarães   2933505  BA
# 4697      18413        Município                Macaúbas   2919801  BA
#
#                    num_pvl    status          num_processo  \
# ...

# %%
# 4) Seu código aqui

data_ba_estado = datalake.loc[(datalake['uf'] == 'BA') & (datalake['tipo_interessado'] == 'Município')]

# %%
data_ba_estado.to_csv('dataframe_ba_exercicio.csv')
